# %% [markdown]
# # Small Assignment 5
#
# Due Monday 11/21 at 11:59 PM

# %% [markdown]
# This assignment focuses on some of the concepts of regression discontuity (RD) designs, using Kim Fe Cramer's [paper](https://www.kimfecramer.com/job-market-paper) about the effects of bank presence on health outcomes in India. The paper leverages a 2005 policy by the Reserve Bank of India (RBI) that offered commercial banks incentives to open branches in underbanked districts.

# %% [markdown]
# ## Part A
#
# Specifically, the RBI offered commercial banks incentives to open branches in underbanked districts, which were defined as those with population to branch ratios above the national average (14,780 people per branch).
#
# 1. Explain why a simple comparison of districts where bank branches opened to other districts would fail to identify causal effects on health outcomes.

# %% [markdown]
# Put your answer here.

# %% [markdown]
# 2. Consider implementing an RD approach based on your knowledge of how the policy was designed. What would the treatment variable be? What would the running variable be?

# %% [markdown]
# Put your answer here.

# %% [markdown]
# 3. Discuss intuitively the assumptions required for this to provide a causal effect of access to banks on health outcomes

# %% [markdown]
# Put your answer here.

# %% [markdown]
# ## Part B
#
# See Figure 6d from the paper below (note that the district level ratio is measured as the difference from the national average and that the bands around the regression lines are 95% confidence intervals. Does it look like the policy significantly affected bank branch openings? Is this a fuzzy or a sharp RD?
#
# ![img1](cramer_fig6d.jpg)

# %% [markdown]
# Put your answer here.

# %% [markdown]
# ## Part C

# %% [markdown]
# Interpret the figures below (in which the outcome variables are all measured _prior_ to the implementation of the policy. What do they suggest about the validity of the RD?
#
# ![img2](attachment:cramer_fig2.png)

# %% [markdown]
# Put your answer here.

# %% [markdown]
# ## Part D
#
# Consider the regression:
#
# $$ \log{daysill_i}=\beta_0+\beta_1underbanked_i\beta_2relative\_ratio_i+\beta_3relative\_ratio_i\times underbanked_i+u_i$$
#
# where $underbanked_i$ equals 1 if a district has above average people per bank branch (pre-policy), and $relative\_ratio_i$ is the ratio of people per bank branch a minus the national average ratio of people per bank branch (pre-policy).
#
# Which variable is the running variable? Which is the treatment variable?
#
# For each of the following, indicate which regression parameter(s) correspond to the description and describe (or draw) where you can see them on the graph below.
#
# 1. The effect of an additional bank branch per capita in underbanked districts.
# 2. The effect of an additional bank branch per capita in well-banked districts.
# 3. The treatment effect (additionally, should we think of this as an ATE, ITT, or TOT?)
# 4. The counterfactual (i.e what we think the average log of days ill would have been in a district with 14,781 bank branches per capita, had the policy not been implemented.
#
#
# ![Figure4.jpg](Figure4.jpg)

# %% [markdown]
# Put your answer here.
